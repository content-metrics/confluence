# %%
properties = [
    "channel_id",
    "channel_views",
    "channel_suscribers",
    "channel_videos",
    "video_hash",
    "publish_at",
    "video_title",
    "video_description",
    "channel_title",
    "video_tags",
    "video_lang",
    "video_views",
    "video_likes",
    "video_comments",
    "video_duration"
    ]


def channel_stats_from_json_to_df(json_file):
    import json
    with open(json_file) as f:
        data =  json.load(f)
    records = []
    for channel_id, channel_info in data.items():
        channel_views = channel_info['channel_statistics']["viewCount"]
        channel_suscribers = channel_info['channel_statistics']["subscriberCount"]
        channel_videos = channel_info['channel_statistics']["videoCount"]

        videos = channel_info["video_data"]
        for video_id, video_info in videos.items():
            video_hash = video_id
            publish_at = video_info["publishedAt"]
            video_title = video_info["title"]
            video_description = video_info["description"]
            channel_title = video_info["channelTitle"]
            video_tags = video_info.get("tags")
            video_lang = video_info.get("defaultAudioLanguage")
            video_views = video_info["viewCount"]
            video_likes = video_info["likeCount"]
            video_comments = video_info["commentCount"]
            video_duration = video_info["duration"]

            properties_values = (
                    channel_id,
                    channel_views,
                    channel_suscribers,
                    channel_videos,
                    video_hash,
                    publish_at,
                    video_title,
                    video_description,
                    channel_title,
                    video_tags,
                    video_lang,
                    video_views,
                    video_likes,
                    video_comments,
                    video_duration
                )
        
            new_row = dict(zip(properties, properties_values))
            records.append(new_row)

    temp_df = pd.DataFrame.from_records(records)
    return temp_df

# %%
file_path = "/Users/elhqdjigagny/Desktop/astrotube/confluence/data/example.json"
temp_df = channel_stats_from_json_to_df(file_path)

# %%
temp_df
# Out:
#                    channel_id channel_views channel_suscribers channel_videos  \
# 0    UCbXgNpp0jedKWcQiULLbDTA      10624878             160000            181
# 1    UCbXgNpp0jedKWcQiULLbDTA      10624878             160000            181
# 2    UCbXgNpp0jedKWcQiULLbDTA      10624878             160000            181
# 3    UCbXgNpp0jedKWcQiULLbDTA      10624878             160000            181
# 4    UCbXgNpp0jedKWcQiULLbDTA      10624878             160000            181
# ..                        ...           ...                ...            ...
# 175  UCbXgNpp0jedKWcQiULLbDTA      10624878             160000            181
# 176  UCbXgNpp0jedKWcQiULLbDTA      10624878             160000            181
# 177  UCbXgNpp0jedKWcQiULLbDTA      10624878             160000            181
# 178  UCbXgNpp0jedKWcQiULLbDTA      10624878             160000            181
# 179  UCbXgNpp0jedKWcQiULLbDTA      10624878             160000            181
#
#       video_hash            publish_at  \
# 0    qAh5dDODJ5k  2022-07-28T14:30:12Z
# 1    lnTPnx9O6nM  2022-07-24T13:36:52Z
# 2    PaGp7Vi5gfM  2022-07-20T14:00:12Z
# 3    07Pxa3TbQc4  2022-07-16T12:00:00Z
# 4    O7CX81quvzE  2022-07-07T14:00:09Z
# ..           ...                   ...
# 175  UdcPhnNjSEw  2019-06-16T09:11:31Z
# 176  e6ivlABOYRI  2019-06-14T18:05:55Z
# 177  Qs3BSFZnZSI  2019-05-28T20:30:09Z
# 178  LTXnQdrwyrw  2019-05-26T16:01:16Z
# 179  Kes8YRV73Io  2019-05-26T13:05:05Z
#
#                                            video_title  \
# 0    HTTPX Tutorial - A next-generation HTTP client...
# 1    How to find N-Largest and N-Smallest Numbers i...
# 2    Schedule Python Scripts with GitHub Actions FO...
# 3     I learned something new about Strings in Python!
# 4      Don't make this mistake with Strings in Python!
# ..                                                 ...
# 175  Collections in Python - Advanced Python 06 - P...
# 176  Strings in Python - Advanced Python 05 - Progr...
# 177  Sets in Python - Advanced Python 04 - Programm...
# 178  Dictionaries in Python - Advanced Python 03 - ...
# 179  Tuples in Python - Advanced Python 02 - Progra...
#
#                                      video_description    channel_title  \
# 0    In this Python Tutorial we learn about HTTPX, ...  Python Engineer
# 1    Quick Python tip how to efficiently find the n...  Python Engineer
# 2    Learn how to schedule Python scripts with GitH...  Python Engineer
# 3    Today I learned a new formatting rule for Stri...  Python Engineer
# 4    Don't forget that Strings are immutable and ma...  Python Engineer
# ..                                                 ...              ...
# 175  Collections in Python - Advanced Python 06 - P...  Python Engineer
# 176  Strings in Python - Advanced Python 05 - Progr...  Python Engineer
# 177  In this Python Advanced Tutorial, we will be l...  Python Engineer
# 178  In this Python Advanced Tutorial we will be le...  Python Engineer
# 179  In this Python Advanced Tutorial, we will be l...  Python Engineer
#
#                                  video_tags video_lang video_views  \
# 0                                  [Python]         en        1407
# 1                                  [Python]         en       25362
# 2                                  [Python]         en       10766
# 3                                  [Python]         en       73018
# 4                                  [Python]         en      122467
# ..                                      ...        ...         ...
# 175         [Python, Programming, Tutorial]       None       52631
# 176  [Python, Programming, Coding, Strings]       None       21816
# 177         [Python, Tutorial, Programming]       None       15258
# 178         [Python, Tutorial, Programming]       None       43101
# 179         [Python, Tutorial, Programming]       None       25057
#
#     video_likes video_comments video_duration
# 0           216              8        PT11M2S
# 1          2167             28          PT27S
# 2           607             34       PT12M33S
# 3          5969             57          PT27S
# 4          6462             69          PT30S
# ..          ...            ...            ...
# 175        1178             58       PT14M10S
# 176         451             46       PT24M16S
# 177         302             32       PT16M19S
# 178         680             53        PT13M5S
# 179         451             26       PT13M31S
#
# [180 rows x 15 columns]
